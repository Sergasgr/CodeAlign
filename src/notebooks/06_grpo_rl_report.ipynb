# %% [markdown]
# # Phase 7 — Advanced RL (GRPO) & Multi-Language Evaluation
#
# This notebook will document the final phase of the JetBrains AI internship project: **comparing DPO against advanced RL techniques like GRPO/PPO**, and extending our validation to **multiple programming languages** (e.g., Rust and Go).
#
# ## Objectives for this Phase
#
# 1. **GRPO vs DPO:** Does a direct gradient approach (DPO) out-compete or under-perform against an online RL method like GRPO (Group Relative Policy Optimization) on this specific alignment task?
# 2. **Multi-Language Robustness:** Up until now, our evaluation focused heavily on Python (using HumanEval and Python linters). In Phase 7, we will run the `bigcode-evaluation-harness` using MultiPL-E to test on Rust and Go, proving the generalizability of our composite reward.
# 3. **Human Preference Validation:** A 50-sample human annotation study to see if developers actually prefer the code produced by the composite reward over the baseline.

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

print("Ready for Phase 7 analysis.")

# %% [markdown]
# ## 1. GRPO vs. DPO (Composite Reward)
#
# *(Pending: This section will be populated once GRPO training is complete and evaluated)*

# %% [markdown]
# ## 2. Multi-Language Pass@1 (Python, Rust, Go)
#
# *(Pending: This section will compare pass@1 metrics across different languages once MultiPL-E evaluation completes)*

# %% [markdown]
# ## 3. Human Preference Study
#
# *(Pending: Results from the 50-sample blind comparison by human annotators)*
